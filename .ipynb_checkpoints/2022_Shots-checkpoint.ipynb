# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
sns.set(rc={"figure.figsize":(20, 8)})

# %%
df = pd.read_csv("shots_2022.csv")
df = df[(df['shotOnEmptyNet']==0)&(df['shotWasOnGoal']>=0)&(df['isPlayoffGame']==0)]
df['teamScoredOn'] = df.apply(lambda x: x['awayTeamCode'] if x['awayTeamGoals']>0 else x['homeTeamCode'], axis=1)
df = df.loc[:, ["shotID", "teamScoredOn", "xCord", "yCord", "goal", "teamCode", "game_id", "goalieNameForShot", "shooterName", "shotAngle", "shotDistance", "shotType", "time"]]

#Map shot quality from 1 to 7 based on distance & if taken from behind the net
    #Rank = 1 if taken outside of offensive zone from distance greater than farthest in-zone point
    #Rank = 2 if taken from anywhere behind goal line or distance >= farthest in-zone point (i.e. between Rank 2 and zone)
    #Rank = 3 if shot was taken outside give y area slot
    #Rank = 4 if shot was taken from farther than 20 feet away from net
    #Rank = 5 if shot was taken from between 10 and 20 feet away from net
    #Rank = 6 if shot was taken  <=10 feet away from net
    #Rank = 7 if shot was taken between faceoff dots <=10 feet away from net
df['quality'] = df.apply(lambda x: 
    1 if (((x['shotDistance'])>=(math.sqrt(64**2 + 42.5**2)))&(x['yCord']<=36)&(x['yCord']>=-36)) else (
    2 if ((x['xCord']<-89)|(x['xCord']>89)|((x['shotDistance'])>=(math.sqrt(64**2 + 42.5**2)))) else(
    3 if (x['yCord']>=30)|(x['yCord']<=-30) else(
    4 if (x['shotDistance']>=20) else(
    5 if (x['shotDistance']>= 10) else (
    6 if (x['shotDistance']>= 5) 
    else 7))))), axis=1)

df_goals=df[df['goal']>0]
def create_circle(coords, c):
    return plt.Circle(xy=(coords[0],coords[1]), radius=15, color=c, fill=False)
def plot_rink(df, title):
    rink = sns.scatterplot(x='xCord', y='yCord', data=df, hue='shotType', alpha=0.5)
    plt.legend(bbox_to_anchor=(1.05,1), loc='upper left', borderaxespad=0)
    plt.title(title)
    #Create rink lines
    rink.axvline(0, color='red')
    rink.axvline(-25, color='blue')
    rink.axvline(25, color='blue')
    rink.axvline(89, color='red')
    rink.axvline(-89, color='red')
    rink.add_patch(createCircle([0,0], 'blue'))
    rink.add_patch(createCircle([69,22], 'red'))
    rink.add_patch(createCircle([-69,22], 'red'))
    rink.add_patch(createCircle([69,-22], 'red'))
    rink.add_patch(createCircle([-69,-22], 'red'))
    rink.grid(False)
df[df['quality']==7]
# Out:
#         shotID teamScoredOn  xCord  yCord  goal teamCode  game_id  \
# 183        183          NYR    -86      3     0      NYR    20003
# 188        188          NYR    -86     -2     0      NYR    20003
# 815        815          VAN     87     -4     0      EDM    20010
# 1214      1214          FLA    -88     -4     1      FLA    20014
# 1405      1405          NYR    -87     -2     1      MIN    20017
# ...        ...          ...    ...    ...   ...      ...      ...
# 113506  113506          PHI     88     -3     0      PHI    21306
# 113629  113629          SJS     87     -4     0      EDM    21308
# 113641  113641          SJS     89     -4     0      EDM    21308
# 113738  113738          VAN     87     -3     1      ARI    21311
# 113926  113926          CBJ    -87      4     0      CBJ    20547
#
#          goalieNameForShot       shooterName  shotAngle  shotDistance  \
# 183     Andrei Vasilevskiy      Jacob Trouba -45.000000      4.242641
# 188     Andrei Vasilevskiy     Chris Kreider  33.690068      3.605551
# 815         Thatcher Demko        Zach Hyman -63.434949      4.472136
# 1214          Ilya Sorokin  Patric Hornqvist  75.963757      4.123106
# 1405       Igor Shesterkin        Matt Boldy  45.000000      2.828427
# ...                    ...               ...        ...           ...
# 113506        Alex Stalock       Kevin Hayes -71.565051      3.162278
# 113629        James Reimer    Connor McDavid -63.434949      4.472136
# 113641        James Reimer   Mattias Janmark -75.963757      4.123106
# 113738        Collin Delia      Liam O'Brien -56.309932      3.605551
# 113926          Devon Levi       Tyler Angle -63.434949      4.472136
#
#        shotType  time  quality
# 183       WRIST   799        7
# 188       WRIST  1041        7
# 815        WRAP   985        7
# 1214       WRAP  2623        7
# 1405       BACK  2780        7
# ...         ...   ...      ...
# 113506     WRAP  1181        7
# 113629     WRAP  2723        7
# 113641    WRIST  3093        7
# 113738      NaN   308        7
# 113926     SNAP  1411        7
#
# [506 rows x 14 columns]

# %%
print(df.corr()['quality']['goal'])
# Out:
# 0.16034013150298557

# %%
df_saves=df[df['goal']==0]
plot_rink(df_saves, "2022-23 Regular Season Non-Empty On Net Shots")

# %%
plot_rink(df_goals, "2022-23 Regular Season Non-Empty Net Goals")
